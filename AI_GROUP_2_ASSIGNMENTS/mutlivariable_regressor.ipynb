# %%
# import packages
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# read data
suicide = pd.read_csv('suicide.csv')

# %%
# split data
X = suicide.drop(columns=['country', 'sex', 'age', 'suicides_no','population', 'suicides/100k pop', 'country-year', 'generation'])

suicides_no = suicide['suicides_no']
X_train, X_test, suicides_no_train, suicides_no_test = train_test_split(X, suicides_no, test_size=0.2)
age = suicide['age']
X_train, X_test, age_train, age_test = train_test_split(X, age, test_size=0.2)
country = suicide['country']
X_train, X_test, country_train, country_test = train_test_split(X, country, test_size=0.2)
sex = suicide['sex']
X_train, X_test, sex_train, sex_test = train_test_split(X, sex, test_size=0.2)

# %%
#Take input
year = input("Enter year: ")
# Out:
# Enter year: 2000

# %%
# plotting the points  
plt.plot(X, suicides_no) 
  
# naming the x axis 
plt.xlabel('Year') 
# naming the y axis 
plt.ylabel('Number of suicides') 
  
# giving a title to my graph 
plt.title('Chart showing the number of suicides from 1985 to 2015') 
  
# function to show the plot 
plt.show()

# %%
print("The number of rows and columns ")
suicide.shape
# Out:
# The number of rows and columns
# (27820, 9)

# %%
suicides_no_model = DecisionTreeRegressor()
#training
suicides_no_model.fit(X_train, suicides_no_train)
suicides_no_predictions = suicides_no_model.predict([ [year] ])
suicides_no_predictions
# Out:
# array([214.82819905])

# %%
age_model = DecisionTreeClassifier()
#training
age_model.fit(X_train, age_train)
age_predictions = age_model.predict([ [year] ])
age_predictions
# Out:
# array(['35-54 years'], dtype=object)

# %%
country_model = DecisionTreeClassifier()
#training
country_model.fit(X_train, country_train)
country_predictions = country_model.predict([ [year] ])
country_predictions
# Out:
# array(['Norway'], dtype=object)

# %%
sex_model = DecisionTreeClassifier()
#training
sex_model.fit(X_train, sex_train)
sex_predictions = sex_model.predict([ [year] ])
sex_predictions
# Out:
# array(['female'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(suicides_no_test, suicides_no_predictions)
cm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d3faaa4f1233> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(suicides_no_test, suicides_no_predictions)
#       3 cm
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
# ...
