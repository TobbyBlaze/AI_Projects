# %%
import twint

# Configure
c = twint.Config()

# %%
# import nest_asyncio
# nest_asyncio.apply()

# %%
# c.Username = "PrissyX6"
# Tobii6661
c.Username = str(input("Enter username: "))
# Out:
# Enter username: PrissyX6

# %%
# c.Search = "."
c.Limit = 20
c.Store_csv = True
c.Output = "tweets"

# %%
# Run
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-a70856039f52> in <module>
#       1 # Run
# ----> 2 twint.run.Search(c)
#
# c:\users\blaze\src\twint\twint\run.py in Search(config, callback)
#     279     config.Profile = False
#     280     config.Profile_full = False
# --> 281     run(config, callback)
#     282     if config.Pandas_au:
#     283         storage.panda._autoget("tweet")
#
# c:\users\blaze\src\twint\twint\run.py in run(config, callback)
#     200 def run(config, callback=None):
#     201     logme.debug(__name__+':run')
# --> 202     get_event_loop().run_until_complete(Twint(config).main(callback))
#     203
#     204 def Favorites(config):
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     569         future.add_done_callback(_run_until_complete_cb)
#     570         try:
# --> 571             self.run_forever()
#     572         except:
#     573             if new_task and future.done() and not future.cancelled():
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_forever(self)
#     524         self._check_closed()
#     525         if self.is_running():
# --> 526             raise RuntimeError('This event loop is already running')
#     527         if events._get_running_loop() is not None:
#     528             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# 1204362060823433216 2019-12-10 11:27:45 Greenwich Standard Time <PrissyX6> I see my death will not even mean anything to anyone
# 1204361992905076736 2019-12-10 11:27:29 Greenwich Standard Time <PrissyX6> I just want to end my life
# 1204361904002609152 2019-12-10 11:27:08 Greenwich Standard Time <PrissyX6> I feel sorry yes yes yes
# 1204361807323906049 2019-12-10 11:26:45 Greenwich Standard Time <PrissyX6> I feel rejected by everyone I have met in my life
# 1203733150507122689 2019-12-08 17:48:42 Greenwich Standard Time <PrissyX6> I am even tired of life
# 1203733067849981952 2019-12-08 17:48:22 Greenwich Standard Time <PrissyX6> No friends. No family
# 1203732572976635904 2019-12-08 17:46:24 Greenwich Standard Time <PrissyX6> Life no sweet no more
# 1203732525631315969 2019-12-08 17:46:13 Greenwich Standard Time <PrissyX6> I'm going on a journey away from this world
# 1203732525237051394 2019-12-08 17:46:12 Greenwich Standard Time <PrissyX6> I'm done with this world
# 1203732048785149952 2019-12-08 17:44:19 Greenwich Standard Time <PrissyX6> Live on a low
# 1203732042887958535 2019-12-08 17:44:17 Greenwich Standard Time <PrissyX6> Expensive summary
# 1203732042883772417 2019-12-08 17:44:17 Greenwich Standard Time <PrissyX6> Tears only I can afford
# 1203732000387059712 2019-12-08 17:44:07 Greenwich Standard Time <PrissyX6> Black soul in white dress
# 1203731999665643520 2019-12-08 17:44:07 Greenwich Standard Time <PrissyX6> Devil in disguise
# 9   17:44:19  Greenwich Standard Time  1201975449267650560  prissyx6
# 10  17:44:17  Greenwich Standard Time  1201975449267650560  prissyx6
# 11  17:44:17  Greenwich Standard Time  1201975449267650560  prissyx6
# 12  17:44:07  Greenwich Standard Time  1201975449267650560  prissyx6
# 13  17:44:07  Greenwich Standard Time  1201975449267650560  prissyx6
# 14  17:44:06  Greenwich Standard Time  1201975449267650560  prissyx6
# 15  17:41:26  Greenwich Standard Time  1201975449267650560  prissyx6
# 16  17:41:16  Greenwich Standard Time  1201975449267650560  prissyx6
# 17  17:40:41  Greenwich Standard Time  1201975449267650560  prissyx6
# 18  17:40:16  Greenwich Standard Time  1201975449267650560  prissyx6
# 19  17:39:37  Greenwich Standard Time  1201975449267650560  prissyx6
#
#         name  place  ... geo source user_rt_id user_rt  retweet_id  \
# 0   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 1   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 2   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 3   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 4   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 5   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 6   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 7   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 8   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 9   Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 10  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 11  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 12  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 13  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 14  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 15  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 16  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 17  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 18  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
# 19  Prissy X    NaN  ... NaN    NaN        NaN     NaN         NaN
#
#                                              reply_to  retweet_date translate  \
# 0   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 1   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 2   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 3   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 4   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 5   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 6   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 7   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 8   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 9   [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 10  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 11  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 12  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 13  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 14  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 15  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 16  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 17  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 18  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
# 19  [{'user_id': '1201975449267650560', 'username'...           NaN       NaN
#
#    trans_src trans_dest
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# 5        NaN        NaN
# 6        NaN        NaN
# 7        NaN        NaN
# 8        NaN        NaN
# 9        NaN        NaN
# 10       NaN        NaN
# 11       NaN        NaN
# 12       NaN        NaN
# 13       NaN        NaN
# 14       NaN        NaN
# 15       NaN        NaN
# 16       NaN        NaN
# 17       NaN        NaN
# 18       NaN        NaN
# 19       NaN        NaN
#
# [20 rows x 34 columns]

# %%
import csv

keys = ["i am depressed", "i want to die", "commit suicide", "my death", "kill myself", "hang myself", "tired of life",
        "feel sorry","heart broken", "feel rejected", "feel frustrated", "feel sad", "feel lonely", "i will be gone",
        "end my life"]

unreal = ["just kidding", "playing", "not serious", "haha", "hahaha", "messing with you", "jokes", "lol", "lmao", "dwl",
          "lmfao", "guy", "guys", "someone", "he", "she"]

alert = 0

with open("tweets/tweets.csv", "r", errors='ignore') as suicide:
    reader = csv.reader(suicide, delimiter=',')
    for lines in reader:
        line = lines[10].lower()
        for i in keys:
            if i in line:
                print(line)
                print(c.Username+" is being followed up...")
                alert += 1
                for k in unreal:
                    if k in line:
                        print(line)
                        print("Oops! "+c.Username+" might just be kidding...")
                        alert -= 1
                        break
        if alert > 3:
            print(c.Username+" is likely to commit suicide!")
            break
# Out:
# i see my death will not even mean anything to anyone
# PrissyX6 is being followed up...
# i just want to end my life
# PrissyX6 is being followed up...
# i feel sorry yes yes yes
# PrissyX6 is being followed up...
# i feel rejected by everyone i have met in my life
# PrissyX6 is being followed up...
# PrissyX6 is likely to commit suicide!
